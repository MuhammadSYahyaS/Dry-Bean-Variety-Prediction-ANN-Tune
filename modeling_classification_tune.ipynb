# %% [markdown]
# # Dry Bean Variety Prediction by Multiclass Classification using ANN with Ray Tune

# %%
import os
import numpy as np
import pandas as pd

import torch

from torch.utils.data import TensorDataset, DataLoader, Dataset
from tqdm.notebook import tqdm
from typing import List

# %% [markdown]
# ## Features and Target to be Used

# %%
x_names = [
    "Area", "Perimeter", "MajorAxisLength", "MinorAxisLength", "Eccentricity", "ConvexArea",
    "EquivDiameter", "Extent", "Solidity", "ShapeFactor1", "ShapeFactor2", "ShapeFactor3", "ShapeFactor4"]
y_name = "Class"
y_classes = ["SEKER", "BARBUNYA", "BOMBAY", "CALI", "DERMASON", "HOROZ", "SIRA"]

# %% [markdown]
# ### Helper functions

# %%
# Convert Pandas dataframe to PyTorch dataset
def df_to_dataset(df: pd.DataFrame) -> Dataset:
    features = df[x_names].to_numpy(dtype=np.float32)
    # preprocess data
    df["Area"] /= 500_000
    df["Perimeter"] /= 5000
    df["MajorAxisLength"] /= 2000
    df["MinorAxisLength"] /= 2000
    df["ConvexArea"] /= 500_000
    df["EquivDiameter"] /= 2000
    # preprocess labels
    labels = df[[y_name]].applymap(lambda x: y_classes.index(x)) # map Class labels to int
    labels = labels.to_numpy(dtype=np.int64).squeeze(axis=1)
    # create the dataset
    features = torch.from_numpy(features)
    labels = torch.from_numpy(labels)
    my_dataset = TensorDataset(features, labels)
    return my_dataset

# %% [markdown]
# ## Train Section

# %% [markdown]
# ### Data Loader

# %%
def load_data(data_dir="DryBeanDataset", batch_size=64):
    df_train = pd.read_csv(os.path.join(data_dir, "dry_bean_train.csv"))
    df_val = pd.read_csv(os.path.join(data_dir, "dry_bean_val.csv"))

    ds_train = df_to_dataset(df_train)
    ds_val = df_to_dataset(df_val)
    # Create PyTorch data loader
    loader_train = DataLoader(ds_train, batch_size=batch_size, shuffle=True, drop_last=True) # drop last for stability
    loader_val = DataLoader(ds_val, batch_size=batch_size)
    return loader_train, loader_val

# %% [markdown]
# ### Model training using Ray Tune

# %%
import logging
import models
import ray

from datetime import datetime
from ray import tune
from ray.air import session, RunConfig, FailureConfig, CheckpointConfig
from ray.air.checkpoint import Checkpoint
from sklearn.metrics import f1_score, accuracy_score

# %%
def train(config: dict, data_dir="DryBeanDataset"):
    # Load the data
    loader_train, loader_val = load_data(data_dir)
    # Which device we will use for training process (CPU/GPU)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print("Using device:", device)
    # Create the model
    model = models.models[config["arch"]](n_features=len(x_names), n_classes=len(y_classes))
    # Move the model from CPU to the device
    # Actually, only required if the device is not CPU and has no effect if it is CPU
    model = model.to(device)
    # Define the loss function and the optimizer
    loss_fn = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=config["init_lr"], betas=(config["beta_1"], config["beta_2"]))
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, min_lr=1e-9)
    # Prepare the logger
    # To restore a checkpoint, use `session.get_checkpoint()`.
    loaded_checkpoint = session.get_checkpoint()
    if loaded_checkpoint:
        with loaded_checkpoint.as_directory() as loaded_checkpoint_dir:
           model_state, optimizer_state = torch.load(os.path.join(loaded_checkpoint_dir, "checkpoint.pt"))
        model.load_state_dict(model_state)
        optimizer.load_state_dict(optimizer_state)
    # The training and validation process
    # Variables to hold some training status
    epoch_number = 0
    # Training loop
    for epoch in range(config["max_epochs"]):
        # Make sure gradient tracking is on, and do a pass over the data for the training process
        model.train()
        running_loss = 0.
        for i, data in enumerate(loader_train):
            # Every data instance is an input & label pair
            inputs, labels = data
            # We move the data instance from CPU to the device
            inputs = inputs.to(device)
            labels = labels.to(device)
            # Zero your gradients for every batch!
            optimizer.zero_grad()
            # Make predictions for this batch
            outputs = model(inputs)
            # Compute the loss and its gradients
            loss = loss_fn(outputs, labels)
            loss.backward()
            # Adjust learning weights
            optimizer.step()
            # Gather data and report
            running_loss += loss.detach().item()
        # Calculate the average training loss
        avg_loss = running_loss / (i + 1)

        # We don't need gradients for the model validation process
        model.eval()
        running_vloss = 0.0
        y_true = []
        y_pred = []
        with torch.no_grad():
            for i, vdata in enumerate(loader_val):
                vinputs, vlabels = vdata
                y_true.extend(vlabels.numpy().tolist())
                voutputs = model(vinputs.to(device))
                vloss = loss_fn(voutputs, vlabels.to(device))
                running_vloss += vloss.item()
                # the class with the highest energy is what we choose as prediction
                _, predicted = torch.max(voutputs.data, 1)
                y_pred.extend(predicted.cpu().numpy().tolist())

        # Calculate the average validation loss
        avg_vloss = running_vloss / (i + 1)
        scheduler.step(avg_vloss)
        # Calculate our classification metrics
        acc = accuracy_score(y_true, y_pred)
        f1 = f1_score(y_true, y_pred, average="weighted")

        # Here we save a checkpoint. It is automatically registered with
        # Ray Tune and can be accessed through `session.get_checkpoint()`
        # API in future iterations.
        # Track best performance, and save the model's state (weights)
        save_dir = os.path.abspath('train')
        os.makedirs(save_dir, exist_ok=True)
        checkpoint_path = os.path.join(save_dir, 'checkpoint.pt')
        torch.save((model.state_dict(), optimizer.state_dict()), checkpoint_path)
        # Log the running loss averaged per batch
        # for both training and validation
        checkpoint = Checkpoint.from_directory(save_dir)
        session.report({
            'train_loss': avg_loss,
            'val_loss': avg_vloss,
            'val_acc': acc,
            'val_weighted_f1': f1
        }, checkpoint=checkpoint)

        epoch_number += 1

# %%
MAX_EPOCHS = 1000

ray.init(ignore_reinit_error=True, num_gpus=1)

param_space = {
    "arch": tune.grid_search(list(models.models.keys())),
    "init_lr": tune.loguniform(1e-2, 1e-6),
    "beta_1": tune.uniform(0.1, 0.9),
    "beta_2": tune.uniform(0.6, 0.99),
    "max_epochs": MAX_EPOCHS
}
tune_config = tune.TuneConfig(
    metric="val_weighted_f1",
    mode="max",
    scheduler=tune.schedulers.ASHAScheduler(max_t=MAX_EPOCHS,grace_period=MAX_EPOCHS//10),
    num_samples=5
)
run_config = RunConfig(
    local_dir="runs_clf_tune",
    stop=tune.stopper.TrialPlateauStopper(metric="val_loss", std=0.02, num_results=MAX_EPOCHS//20, grace_period=MAX_EPOCHS//10),
    failure_config=FailureConfig(fail_fast=True),
    sync_config=tune.SyncConfig(),
    progress_reporter=tune.JupyterNotebookReporter(),
    log_to_file=True,
    checkpoint_config=CheckpointConfig(
        num_to_keep=1,
        checkpoint_score_attribute="val_weighted_f1",
        checkpoint_score_order="max",
        checkpoint_at_end=True
    ),
)

tuner = tune.Tuner(
    tune.with_resources(
        tune.with_parameters(train, data_dir=os.path.abspath("DryBeanDataset")),
        {"cpu": 2, "gpu": 0.2}),
    tune_config=tune_config,
    param_space=param_space,
    run_config=run_config)
results = tuner.fit()
# Out:
# == Status ==<br>Current time: 2022-09-05 19:58:11 (running for 00:09:40.56)<br>Memory usage on this node: 4.2/50.0 GiB<br>Using AsyncHyperBand: num_stopped=5
# Bracket: Iter 400.000: None | Iter 100.000: 0.6555542405396327<br>Resources requested: 0/16 CPUs, 0/1 GPUs, 0.0/28.92 GiB heap, 0.0/14.46 GiB objects<br>Current best trial: 0baf6_00019 with val_weighted_f1=0.9119572192332976 and parameters={'arch': 'MLP6Layers', 'init_lr': 0.00013011698059279522, 'beta_1': 0.6271696733634531, 'beta_2': 0.6816242674528422, 'max_epochs': 1000}<br>Result logdir: /mnt/d/Projects/stiki_malang_2022/Dry-Bean-Variety-Prediction-ANN-Tune/runs_clf_tune/train_2022-09-05_19-48-31<br>Number of trials: 20/20 (20 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name       </th><th>status    </th><th>loc                 </th><th>arch      </th><th style="text-align: right;">  beta_1</th><th style="text-align: right;">  beta_2</th><th style="text-align: right;">    init_lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  train_loss</th><th style="text-align: right;">  val_loss</th><th style="text-align: right;">  val_acc</th></tr>
# </thead>
# <tbody>
# <tr><td>train_0baf6_00000</td><td>TERMINATED</td><td>172.24.150.175:30209</td><td>MLP3Layers</td><td style="text-align: right;">0.456297</td><td style="text-align: right;">0.963005</td><td style="text-align: right;">2.25669e-06</td><td style="text-align: right;">   242</td><td style="text-align: right;">        159.611 </td><td style="text-align: right;">    0.982509</td><td style="text-align: right;">  0.95766 </td><td style="text-align: right;"> 0.674504</td></tr>
# <tr><td>train_0baf6_00001</td><td>TERMINATED</td><td>172.24.150.175:30236</td><td>MLP4Layers</td><td style="text-align: right;">0.153105</td><td style="text-align: right;">0.611412</td><td style="text-align: right;">8.48668e-05</td><td style="text-align: right;">   114</td><td style="text-align: right;">         80.3952</td><td style="text-align: right;">    0.872285</td><td style="text-align: right;">  0.82679 </td><td style="text-align: right;"> 0.677443</td></tr>
# <tr><td>train_0baf6_00002</td><td>TERMINATED</td><td>172.24.150.175:30238</td><td>MLP5Layers</td><td style="text-align: right;">0.660713</td><td style="text-align: right;">0.79081 </td><td style="text-align: right;">2.64964e-06</td><td style="text-align: right;">   100</td><td style="text-align: right;">         84.7074</td><td style="text-align: right;">    1.38264 </td><td style="text-align: right;">  1.39001 </td><td style="text-align: right;"> 0.37399 </td></tr>
# <tr><td>train_0baf6_00003</td><td>TERMINATED</td><td>172.24.150.175:30241</td><td>MLP6Layers</td><td style="text-align: right;">0.419534</td><td style="text-align: right;">0.607438</td><td style="text-align: right;">7.68568e-06</td><td style="text-align: right;">   100</td><td style="text-align: right;">        144.28  </td><td style="text-align: right;">    1.17997 </td><td style="text-align: right;">  1.20276 </td><td style="text-align: right;"> 0.549596</td></tr>
# <tr><td>train_0baf6_00004</td><td>TERMINATED</td><td>172.24.150.175:30244</td><td>MLP3Layers</td><td style="text-align: right;">0.492631</td><td style="text-align: right;">0.618265</td><td style="text-align: right;">0.00166074 </td><td style="text-align: right;">   100</td><td style="text-align: right;">         65.832 </td><td style="text-align: right;">    1.83743 </td><td style="text-align: right;">  1.84069 </td><td style="text-align: right;"> 0.249082</td></tr>
# <tr><td>train_0baf6_00005</td><td>TERMINATED</td><td>172.24.150.175:30244</td><td>MLP4Layers</td><td style="text-align: right;">0.616983</td><td style="text-align: right;">0.978244</td><td style="text-align: right;">0.000268894</td><td style="text-align: right;">   100</td><td style="text-align: right;">         68.8361</td><td style="text-align: right;">    1.83766 </td><td style="text-align: right;">  1.84047 </td><td style="text-align: right;"> 0.249082</td></tr>
# <tr><td>train_0baf6_00006</td><td>TERMINATED</td><td>172.24.150.175:30236</td><td>MLP5Layers</td><td style="text-align: right;">0.824499</td><td style="text-align: right;">0.794034</td><td style="text-align: right;">1.37914e-05</td><td style="text-align: right;">   100</td><td style="text-align: right;">         82.787 </td><td style="text-align: right;">    1.36034 </td><td style="text-align: right;">  1.34985 </td><td style="text-align: right;"> 0.478325</td></tr>
# <tr><td>train_0baf6_00007</td><td>TERMINATED</td><td>172.24.150.175:30238</td><td>MLP6Layers</td><td style="text-align: right;">0.78316 </td><td style="text-align: right;">0.843288</td><td style="text-align: right;">0.000680648</td><td style="text-align: right;">   100</td><td style="text-align: right;">        149.215 </td><td style="text-align: right;">    1.8376  </td><td style="text-align: right;">  1.84053 </td><td style="text-align: right;"> 0.249082</td></tr>
# <tr><td>train_0baf6_00008</td><td>TERMINATED</td><td>172.24.150.175:30244</td><td>MLP3Layers</td><td style="text-align: right;">0.849601</td><td style="text-align: right;">0.682178</td><td style="text-align: right;">0.000196229</td><td style="text-align: right;">   152</td><td style="text-align: right;">         98.655 </td><td style="text-align: right;">    1.5659  </td><td style="text-align: right;">  1.32204 </td><td style="text-align: right;"> 0.76194 </td></tr>
# <tr><td>train_0baf6_00009</td><td>TERMINATED</td><td>172.24.150.175:30241</td><td>MLP4Layers</td><td style="text-align: right;">0.598643</td><td style="text-align: right;">0.672967</td><td style="text-align: right;">0.000692481</td><td style="text-align: right;">   100</td><td style="text-align: right;">         69.0889</td><td style="text-align: right;">    1.83775 </td><td style="text-align: right;">  1.84054 </td><td style="text-align: right;"> 0.249082</td></tr>
# <tr><td>train_0baf6_00010</td><td>TERMINATED</td><td>172.24.150.175:30209</td><td>MLP5Layers</td><td style="text-align: right;">0.824063</td><td style="text-align: right;">0.973956</td><td style="text-align: right;">0.000452437</td><td style="text-align: right;">   100</td><td style="text-align: right;">         83.8905</td><td style="text-align: right;">    1.83733 </td><td style="text-align: right;">  1.84052 </td><td style="text-align: right;"> 0.249082</td></tr>
# <tr><td>train_0baf6_00011</td><td>TERMINATED</td><td>172.24.150.175:30236</td><td>MLP6Layers</td><td style="text-align: right;">0.512494</td><td style="text-align: right;">0.793377</td><td style="text-align: right;">2.06069e-05</td><td style="text-align: right;">   276</td><td style="text-align: right;">        370.024 </td><td style="text-align: right;">    0.584261</td><td style="text-align: right;">  0.536306</td><td style="text-align: right;"> 0.818516</td></tr>
# <tr><td>train_0baf6_00012</td><td>TERMINATED</td><td>172.24.150.175:30241</td><td>MLP3Layers</td><td style="text-align: right;">0.682991</td><td style="text-align: right;">0.989896</td><td style="text-align: right;">3.07306e-05</td><td style="text-align: right;">   164</td><td style="text-align: right;">        109.458 </td><td style="text-align: right;">    1.18573 </td><td style="text-align: right;">  0.994806</td><td style="text-align: right;"> 0.725937</td></tr>
# <tr><td>train_0baf6_00013</td><td>TERMINATED</td><td>172.24.150.175:30244</td><td>MLP4Layers</td><td style="text-align: right;">0.763549</td><td style="text-align: right;">0.92353 </td><td style="text-align: right;">9.51508e-06</td><td style="text-align: right;">   100</td><td style="text-align: right;">         70.2972</td><td style="text-align: right;">    1.31341 </td><td style="text-align: right;">  1.28742 </td><td style="text-align: right;"> 0.468773</td></tr>
# <tr><td>train_0baf6_00014</td><td>TERMINATED</td><td>172.24.150.175:30238</td><td>MLP5Layers</td><td style="text-align: right;">0.645914</td><td style="text-align: right;">0.955114</td><td st
# 2022-09-05 19:48:31,178	WARNING function_trainable.py:619 -- Function checkpointing is disabled. This may result in unexpected behavior when using checkpointing features or certain schedulers. To enable, set the train function arguments to be `func(config, checkpoint_dir=None)`.
# (train pid=30209) Using device: cuda
# (train pid=30238) Using device: cuda
# (train pid=30236) Using device: cuda
# (train pid=30241) Using device: cuda
# (train pid=30244) Using device: cuda
# Result for train_0baf6_00000:
#   date: 2022-09-05_19-48-38
#   done: false
#   experiment_id: 6bd7c4f9da5b45f9a7bf13f058dd95cd
#   hostname: MSI
#   iterations_since_restore: 1
#   node_ip: 172.24.150.175
#   pid: 30209
#   should_checkpoint: true
#   time_since_restore: 4.053349494934082
#   time_this_iter_s: 4.053349494934082
#   time_total_s: 4.053349494934082
#   timestamp: 1662382118
#   timesteps_since_restore: 0
#   train_loss: 339.6617796968769
#   training_iteration: 1
#   trial_id: 0baf6_00000
#   val_acc: 0.20132255694342396
#   val_loss: 11.553337443958629
#   val_weighted_f1: 0.07938693321218257
#   warmup_time: 0.002660036087036133
#
# Result for train_0baf6_00004:
#   date: 2022-09-05_19-48-39
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 1
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 3.1829795837402344
#   time_this_iter_s: 3.1829795837402344
#   time_total_s: 3.1829795837402344
#   timestamp: 1662382119
#   timesteps_since_restore: 0
#   train_loss: 926.1625817023419
#   training_iteration: 1
#   trial_id: 0baf6_00004
#   val_acc: 0.2490815576781778
#   val_loss: 1.9095887758515098
#   val_weighted_f1: 0.0993395859445909
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00001:
#   date: 2022-09-05_19-48-39
#   done: false
#   experiment_id: 463ac68dc8884a55bc94b18ae18f3af9
#   hostname: MSI
#   iterations_since_restore: 1
#   node_ip: 172.24.150.175
#   pid: 30236
#   should_checkpoint: true
#   time_since_restore: 3.375331401824951
#   time_this_iter_s: 3.375331401824951
#   time_total_s: 3.375331401824951
#   timestamp: 1662382119
#   timesteps_since_restore: 0
#   train_loss: 123.2864305135366
#   training_iteration: 1
#   trial_id: 0baf6_00001
#   val_acc: 0.03747244673034533
#   val_loss: 157.2455159967596
#   val_weighted_f1: 0.0027069331207473257
#   warmup_time: 0.0032007694244384766
#
# Result for train_0baf6_00002:
#   date: 2022-09-05_19-48-39
#   done: false
#   experiment_id: 1ad0af4e80e5422d9254d1cd42e38dd8
#   hostname: MSI
#   iterations_since_restore: 1
#   node_ip: 172.24.150.175
#   pid: 30238
#   should_checkpoint: true
#   time_since_restore: 3.4090182781219482
#   time_this_iter_s: 3.4090182781219482
#   time_total_s: 3.4090182781219482
#   timestamp: 1662382119
#   timesteps_since_restore: 0
#   train_loss: 92.75429639703519
#   training_iteration: 1
#   trial_id: 0baf6_00002
#   val_acc: 0.2799412196914034
#   val_loss: 2.207028708674691
#   val_weighted_f1: 0.15849289280776893
#   warmup_time: 0.0031316280364990234
#
# Result for train_0baf6_00003:
#   date: 2022-09-05_19-48-40
#   done: false
#   experiment_id: 6cfa0e02f14241c5bc9a298bdc945322
#   hostname: MSI
#   iterations_since_restore: 1
#   node_ip: 172.24.150.175
#   pid: 30241
#   should_checkpoint: true
#   time_since_restore: 4.012319803237915
#   time_this_iter_s: 4.012319803237915
#   time_total_s: 4.012319803237915
#   timestamp: 1662382120
#   timesteps_since_restore: 0
#   train_loss: 14.51285862278294
#   training_iteration: 1
#   trial_id: 0baf6_00003
#   val_acc: 0.05363703159441587
#   val_loss: 11.23032114722512
#   val_weighted_f1: 0.012374624554250261
#   warmup_time: 0.004381895065307617
#
# Result for train_0baf6_00000:
#   date: 2022-09-05_19-48-43
#   done: false
#   experiment_id: 6bd7c4f9da5b45f9a7bf13f058dd95cd
#   hostname: MSI
#   iterations_since_restore: 9
#   node_ip: 172.24.150.175
#   pid: 30209
#   should_checkpoint: true
#   time_since_restore: 9.085218906402588
#   time_this_iter_s: 0.6580867767333984
#   time_total_s: 9.085218906402588
#   timestamp: 1662382123
#   timesteps_since_restore: 0
#   train_loss: 10.738671479998407
#   training_iteration: 9
#   trial_id: 0baf6_00000
#   val_acc: 0.23806024981631155
#   val_loss: 9.34640184315768
#   val_weighted_f1: 0.16738286498508373
#   warmup_time: 0.002660036087036133
#
# Result for train_0baf6_00001:
#   date: 2022-09-05_19-48-44
#   done: false
#   experiment_id: 463ac68dc8884a55bc94b18ae18f3af9
#   hostname: MSI
#   iterations_since_restore: 9
#   node_ip: 172.24.150.175
#   pid: 30236
#   should_checkpoint: true
#   time_since_restore: 8.743149280548096
#   time_this_iter_s: 0.659292459487915
#   time_total_s: 8.743149280548096
#   timestamp: 1662382124
#   timesteps_since_restore: 0
#   train_loss: 73.95066216185286
#   training_iteration: 9
#   trial_id: 0baf6_00001
#   val_acc: 0.14401175606171931
#   val_loss: 77.52517561479048
#   val_weighted_f1: 0.03625729503930249
#   warmup_time: 0.0032007694244384766
#
# Result for train_0baf6_00004:
#   date: 2022-09-05_19-48-45
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 10
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 8.831584453582764
#   time_this_iter_s: 0.7129006385803223
#   time_total_s: 8.831584453582764
#   timestamp: 1662382125
#   timesteps_since_restore: 0
#   train_loss: 1.8377949845146488
#   training_iteration: 10
#   trial_id: 0baf6_00004
#   val_acc: 0.2490815576781778
#   val_loss: 1.8405373800884595
#   val_weighted_f1: 0.0993395859445909
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00002:
#   date: 2022-09-05_19-48-45
#   done: false
#   experiment_id: 1ad0af4e80e5422d9254d1cd42e38dd8
#   hostname: MSI
#   iterations_since_restore: 8
#   node_ip: 172.24.150.175
#   pid: 30238
#   should_checkpoint: true
#   time_since_restore: 9.133487462997437
#   time_this_iter_s: 0.8830575942993164
#   time_total_s: 9.133487462997437
#   timestamp: 1662382125
#   timesteps_since_restore: 0
#   train_loss: 2.2136724011318103
#   training_iteration: 8
#   trial_id: 0baf6_00002
#   val_acc: 0.20867009551800147
#   val_loss: 2.217631161212921
#   val_weighted_f1: 0.10540849256113005
#   warmup_time: 0.0031316280364990234
#
# Result for train_0baf6_00003:
#   date: 2022-09-05_19-48-45
#   done: false
#   experiment_id: 6cfa0e02f14241c5bc9a298bdc945322
#   hostname: MSI
#   iterations_since_restore: 5
#   node_ip: 172.24.150.175
#   pid: 30241
#   should_checkpoint: true
#   time_since_restore: 9.626188516616821
#   time_this_iter_s: 1.437107801437378
#   time_total_s: 9.626188516616821
#   timestamp: 1662382125
#   timesteps_since_restore: 0
#   train_loss: 8.86802929317629
#   training_iteration: 5
#   trial_id: 0baf6_00003
#   val_acc: 0.03747244673034533
#   val_loss: 9.144295519048518
#   val_weighted_f1: 0.0027069331207473257
#   warmup_time: 0.004381895065307617
#
# Result for train_0baf6_00000:
#   date: 2022-09-05_19-48-48
#   done: false
#   experiment_id: 6bd7c4f9da5b45f9a7bf13f058dd95cd
#   hostname: MSI
#   iterations_since_restore: 17
#   node_ip: 172.24.150.175
#   pid: 30209
#   should_checkpoint: true
#   time_since_restore: 14.452872037887573
#   time_this_iter_s: 0.542799711227417
#   time_total_s: 14.452872037887573
#   timestamp: 1662382128
#   timesteps_since_restore: 0
#   train_loss: 9.613924248798474
#   training_iteration: 17
#   trial_id: 0baf6_00000
#   val_acc: 0.21675238795003673
#   val_loss: 9.592923749576915
#   val_weighted_f1: 0.14470251467900422
#   warmup_time: 0.002660036087036133
#
# Result for train_0baf6_00002:
#   date: 2022-09-05_19-48-50
#   done: false
#   experiment_id: 1ad0af4e80e5422d9254d1cd42e38dd8
#   hostname: MSI
#   iterations_since_restore: 14
#   node_ip: 172.24.150.175
#   pid: 30238
#   should_checkpoint: true
#   time_since_restore: 14.151198863983154
#   time_this_iter_s: 0.7019107341766357
#   time_total_s: 14.151198863983154
#   timestamp: 1662382130
#   timesteps_since_restore: 0
#   train_loss: 2.1103515568617226
#   training_iteration: 14
#   trial_id: 0baf6_00002
#   val_acc: 0.13592946362968406
#   val_loss: 2.477219657464461
#   val_weighted_f1: 0.052900370173393614
#   warmup_time: 0.0031316280364990234
#
# Result for train_0baf6_00004:
#   date: 2022-09-05_19-48-50
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 18
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 14.18694543838501
#   time_this_iter_s: 0.618687629699707
#   time_total_s: 14.18694543838501
#   timestamp: 1662382130
#   timesteps_since_restore: 0
#   train_loss: 1.838299563607654
#   training_iteration: 18
#   trial_id: 0baf6_00004
#   val_acc: 0.2490815576781778
#   val_loss: 1.8405771851539612
#   val_weighted_f1: 0.0993395859445909
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00001:
#   date: 2022-09-05_19-48-50
#   done: false
#   experiment_id: 463ac68dc8884a55bc94b18ae18f3af9
#   hostname: MSI
#   iterations_since_restore: 17
#   node_ip: 172.24.150.175
#   pid: 30236
#   should_checkpoint: true
#   time_since_restore: 14.39814305305481
#   time_this_iter_s: 0.662487268447876
#   time_total_s: 14.39814305305481
#   timestamp: 1662382130
#   timesteps_since_restore: 0
#   train_loss: 3.891235851758235
#   training_iteration: 17
#   trial_id: 0baf6_00001
#   val_acc: 0.4592211609110948
#   val_loss: 3.4215884750539605
#   val_weighted_f1: 0.34668854548162
#   warmup_time: 0.0032007694244384766
#
# Result for train_0baf6_00003:
#   date: 2022-09-05_19-48-51
#   done: false
#   experiment_id: 6cfa0e02f14241c5bc9a298bdc945322
#   hostname: MSI
#   iterations_since_restore: 9
#   node_ip: 172.24.150.175
#   pid: 30241
#   should_checkpoint: true
#   time_since_restore: 15.216191530227661
#   time_this_iter_s: 1.3621680736541748
#   time_total_s: 15.216191530227661
#   timestamp: 1662382131
#   timesteps_since_restore: 0
#   train_loss: 7.813237628421268
#   training_iteration: 9
#   trial_id: 0baf6_00003
#   val_acc: 0.20132255694342396
#   val_loss: 5.589994408867576
#   val_weighted_f1: 0.10731034662154285
#   warmup_time: 0.004381895065307617
#
# Result for train_0baf6_00000:
#   date: 2022-09-05_19-48-54
#   done: false
#   experiment_id: 6bd7c4f9da5b45f9a7bf13f058dd95cd
#   hostname: MSI
#   iterations_since_restore: 25
#   node_ip: 172.24.150.175
#   pid: 30209
#   should_checkpoint: true
#   time_since_restore: 19.625255584716797
#   time_this_iter_s: 0.6266219615936279
#   time_total_s: 19.625255584716797
#   timestamp: 1662382134
#   timesteps_since_restore: 0
#   train_loss: 8.927130381803256
#   training_iteration: 25
#   trial_id: 0baf6_00000
#   val_acc: 0.3666421748714181
#   val_loss: 10.535219019109553
#   val_weighted_f1: 0.26972259605020665
#   warmup_time: 0.002660036087036133
#
# Result for train_0baf6_00002:
#   date: 2022-09-05_19-48-55
#   done: false
#   experiment_id: 1ad0af4e80e5422d9254d1cd42e38dd8
#   hostname: MSI
#   iterations_since_restore: 21
#   node_ip: 172.24.150.175
#   pid: 30238
#   should_checkpoint: true
#   time_since_restore: 19.85770034790039
#   time_this_iter_s: 0.8241567611694336
#   time_total_s: 19.85770034790039
#   timestamp: 1662382135
#   timesteps_since_restore: 0
#   train_loss: 1.4940329492092133
#   training_iteration: 21
#   trial_id: 0baf6_00002
#   val_acc: 0.21381337252020574
#   val_loss: 1.4640596563165837
#   val_weighted_f1: 0.19068767229601566
#   warmup_time: 0.0031316280364990234
#
# Result for train_0baf6_00001:
#   date: 2022-09-05_19-48-56
#   done: false
#   experiment_id: 463ac68dc8884a55bc94b18ae18f3af9
#   hostname: MSI
#   iterations_since_restore: 25
#   node_ip: 172.24.150.175
#   pid: 30236
#   should_checkpoint: true
#   time_since_restore: 19.87968349456787
#   time_this_iter_s: 0.6764986515045166
#   time_total_s: 19.87968349456787
#   timestamp: 1662382136
#   timesteps_since_restore: 0
#   train_loss: 3.9188298711905607
#   training_iteration: 25
#   trial_id: 0baf6_00001
#   val_acc: 0.2909625275532697
#   val_loss: 4.012703960592097
#   val_weighted_f1: 0.22798359223148115
#   warmup_time: 0.0032007694244384766
#
# Result for train_0baf6_00004:
#   date: 2022-09-05_19-48-56
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 27
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 19.79577136039734
#   time_this_iter_s: 0.6329500675201416
#   time_total_s: 19.79577136039734
#   timestamp: 1662382136
#   timesteps_since_restore: 0
#   train_loss: 1.83708272350801
#   training_iteration: 27
#   trial_id: 0baf6_00004
#   val_acc: 0.2490815576781778
#   val_loss: 1.8407685865055432
#   val_weighted_f1: 0.0993395859445909
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00003:
#   date: 2022-09-05_19-48-56
#   done: false
#   experiment_id: 6cfa0e02f14241c5bc9a298bdc945322
#   hostname: MSI
#   iterations_since_restore: 13
#   node_ip: 172.24.150.175
#   pid: 30241
#   should_checkpoint: true
#   time_since_restore: 20.75736117362976
#   time_this_iter_s: 1.3986239433288574
#   time_total_s: 20.75736117362976
#   timestamp: 1662382136
#   timesteps_since_restore: 0
#   train_loss: 7.26511017051903
#   training_iteration: 13
#   trial_id: 0baf6_00003
#   val_acc: 0.0940484937545922
#   val_loss: 6.708056601611051
#   val_weighted_f1: 0.016169519409788852
#   warmup_time: 0.004381895065307617
#
# Result for train_0baf6_00000:
#   date: 2022-09-05_19-48-59
#   done: false
#   experiment_id: 6bd7c4f9da5b45f9a7bf13f058dd95cd
#   hostname: MSI
#   iterations_since_restore: 33
#   node_ip: 172.24.150.175
#   pid: 30209
#   should_checkpoint: true
#   time_since_restore: 24.79576349258423
#   time_this_iter_s: 0.6969444751739502
#   time_total_s: 24.79576349258423
#   timestamp: 1662382139
#   timesteps_since_restore: 0
#   train_loss: 8.275013238997072
#   training_iteration: 33
#   trial_id: 0baf6_00000
#   val_acc: 0.2872887582659809
#   val_loss: 9.686638853766702
#   val_weighted_f1: 0.16644111742483958
#   warmup_time: 0.002660036087036133
#
# Result for train_0baf6_00004:
#   date: 2022-09-05_19-49-01
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 35
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 24.91134023666382
#   time_this_iter_s: 0.5219912528991699
#   time_total_s: 24.91134023666382
#   timestamp: 1662382141
#   timesteps_since_restore: 0
#   train_loss: 1.838037367608096
#   training_iteration: 35
#   trial_id: 0baf6_00004
#   val_acc: 0.2490815576781778
#   val_loss: 1.8407033302567222
#   val_weighted_f1: 0.0993395859445909
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00001:
#   date: 2022-09-05_19-49-01
#   done: false
#   experiment_id: 463ac68dc8884a55bc94b18ae18f3af9
#   hostname: MSI
#   iterations_since_restore: 33
#   node_ip: 172.24.150.175
#   pid: 30236
#   should_checkpoint: true
#   time_since_restore: 25.32555651664734
#   time_this_iter_s: 0.6697099208831787
#   time_total_s: 25.32555651664734
#   timestamp: 1662382141
#   timesteps_since_restore: 0
#   train_loss: 0.9860034371550018
#   training_iteration: 33
#   trial_id: 0baf6_00001
#   val_acc: 0.6032329169728141
#   val_loss: 0.8971318521282889
#   val_weighted_f1: 0.5598157596356007
#   warmup_time: 0.0032007694244384766
#
# Result for train_0baf6_00002:
#   date: 2022-09-05_19-49-01
#   done: false
#   experiment_id: 1ad0af4e80e5422d9254d1cd42e38dd8
#   hostname: MSI
#   iterations_since_restore: 28
#   node_ip: 172.24.150.175
#   pid: 30238
#   should_checkpoint: true
#   time_since_restore: 25.54383397102356
#   time_this_iter_s: 0.8318562507629395
#   time_total_s: 25.54383397102356
#   timestamp: 1662382141
#   timesteps_since_restore: 0
#   train_loss: 1.4843371550779085
#   training_iteration: 28
#   trial_id: 0baf6_00002
#   val_acc: 0.21234386480529022
#   val_loss: 1.4578342762860386
#   val_weighted_f1: 0.2142996773410448
#   warmup_time: 0.0031316280364990234
#
# Result for train_0baf6_00003:
#   date: 2022-09-05_19-49-02
#   done: false
#   experiment_id: 6cfa0e02f14241c5bc9a298bdc945322
#   hostname: MSI
#   iterations_since_restore: 17
#   node_ip: 172.24.150.175
#   pid: 30241
#   should_checkpoint: true
#   time_since_restore: 26.31283664703369
#   time_this_iter_s: 1.4109110832214355
#   time_total_s: 26.31283664703369
#   timestamp: 1662382142
#   timesteps_since_restore: 0
#   train_loss: 6.473358284782719
#   training_iteration: 17
#   trial_id: 0baf6_00003
#   val_acc: 0.1109478324761205
#   val_loss: 7.896707881580699
#   val_weighted_f1: 0.022160215216791266
#   warmup_time: 0.004381895065307617
#
# Result for train_0baf6_00000:
#   date: 2022-09-05_19-49-04
#   done: false
#   experiment_id: 6bd7c4f9da5b45f9a7bf13f058dd95cd
#   hostname: MSI
#   iterations_since_restore: 42
#   node_ip: 172.24.150.175
#   pid: 30209
#   should_checkpoint: true
#   time_since_restore: 30.347975969314575
#   time_this_iter_s: 0.7204935550689697
#   time_total_s: 30.347975969314575
#   timestamp: 1662382144
#   timesteps_since_restore: 0
#   train_loss: 7.941671906290828
#   training_iteration: 42
#   trial_id: 0baf6_00000
#   val_acc: 0.3982365907421014
#   val_loss: 4.627402890812267
#   val_weighted_f1: 0.286081334970339
#   warmup_time: 0.002660036087036133
#
# Result for train_0baf6_00004:
#   date: 2022-09-05_19-49-06
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 43
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 30.014060974121094
#   time_this_iter_s: 0.6398460865020752
#   time_total_s: 30.014060974121094
#   timestamp: 1662382146
#   timesteps_since_restore: 0
#   train_loss: 1.8374035793381769
#   training_iteration: 43
#   trial_id: 0baf6_00004
#   val_acc: 0.2490815576781778
#   val_loss: 1.8406961939551614
#   val_weighted_f1: 0.0993395859445909
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00001:
#   date: 2022-09-05_19-49-06
#   done: false
#   experiment_id: 463ac68dc8884a55bc94b18ae18f3af9
#   hostname: MSI
#   iterations_since_restore: 41
#   node_ip: 172.24.150.175
#   pid: 30236
#   should_checkpoint: true
#   time_since_restore: 30.644946098327637
#   time_this_iter_s: 0.5895671844482422
#   time_total_s: 30.644946098327637
#   timestamp: 1662382146
#   timesteps_since_restore: 0
#   train_loss: 0.9677765244567716
#   training_iteration: 41
#   trial_id: 0baf6_00001
#   val_acc: 0.6421748714180749
#   val_loss: 0.8786117461594668
#   val_weighted_f1: 0.6306350788015261
#   warmup_time: 0.0032007694244384766
#
# Result for train_0baf6_00002:
#   date: 2022-09-05_19-49-07
#   done: false
#   experiment_id: 1ad0af4e80e5422d9254d1cd42e38dd8
#   hostname: MSI
#   iterations_since_restore: 35
#   node_ip: 172.24.150.175
#   pid: 30238
#   should_checkpoint: true
#   time_since_restore: 31.26784038543701
#   time_this_iter_s: 0.8556547164916992
#   time_total_s: 31.26784038543701
#   timestamp: 1662382147
#   timesteps_since_restore: 0
#   train_loss: 1.4778927725714606
#   training_iteration: 35
#   trial_id: 0baf6_00002
#   val_acc: 0.26965466568699487
#   val_loss: 1.4443558237769387
#   val_weighted_f1: 0.22005046857545266
#   warmup_time: 0.0031316280364990234
#
# Result for train_0baf6_00003:
#   date: 2022-09-05_19-49-07
#   done: false
#   experiment_id: 6cfa0e02f14241c5bc9a298bdc945322
#   hostname: MSI
#   iterations_since_restore: 21
#   node_ip: 172.24.150.175
#   pid: 30241
#   should_checkpoint: true
#   time_since_restore: 31.76449942588806
#   time_this_iter_s: 1.4039180278778076
#   time_total_s: 31.76449942588806
#   timestamp: 1662382147
#   timesteps_since_restore: 0
#   train_loss: 5.83778220576209
#   training_iteration: 21
#   trial_id: 0baf6_00003
#   val_acc: 0.03747244673034533
#   val_loss: 6.104515899311412
#   val_weighted_f1: 0.003132942267619037
#   warmup_time: 0.004381895065307617
#
# Result for train_0baf6_00000:
#   date: 2022-09-05_19-49-10
#   done: false
#   experiment_id: 6bd7c4f9da5b45f9a7bf13f058dd95cd
#   hostname: MSI
#   iterations_since_restore: 51
#   node_ip: 172.24.150.175
#   pid: 30209
#   should_checkpoint: true
#   time_since_restore: 35.92410659790039
#   time_this_iter_s: 0.716036319732666
#   time_total_s: 35.92410659790039
#   timestamp: 1662382150
#   timesteps_since_restore: 0
#   train_loss: 7.17080490814673
#   training_iteration: 51
#   trial_id: 0baf6_00000
#   val_acc: 0.33210874357090375
#   val_loss: 9.04453665559942
#   val_weighted_f1: 0.2556910467203701
#   warmup_time: 0.002660036087036133
#
# Result for train_0baf6_00004:
#   date: 2022-09-05_19-49-11
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 52
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 35.613510608673096
#   time_this_iter_s: 0.6163763999938965
#   time_total_s: 35.613510608673096
#   timestamp: 1662382151
#   timesteps_since_restore: 0
#   train_loss: 1.8372265197135307
#   training_iteration: 52
#   trial_id: 0baf6_00004
#   val_acc: 0.2490815576781778
#   val_loss: 1.840694779699499
#   val_weighted_f1: 0.0993395859445909
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00001:
#   date: 2022-09-05_19-49-12
#   done: false
#   experiment_id: 463ac68dc8884a55bc94b18ae18f3af9
#   hostname: MSI
#   iterations_since_restore: 49
#   node_ip: 172.24.150.175
#   pid: 30236
#   should_checkpoint: true
#   time_since_restore: 36.01834034919739
#   time_this_iter_s: 0.6232757568359375
#   time_total_s: 36.01834034919739
#   timestamp: 1662382152
#   timesteps_since_restore: 0
#   train_loss: 0.9585638726885254
#   training_iteration: 49
#   trial_id: 0baf6_00001
#   val_acc: 0.5973548861131521
#   val_loss: 0.9332285902716897
#   val_weighted_f1: 0.565666258397039
#   warmup_time: 0.0032007694244384766
#
# Result for train_0baf6_00002:
#   date: 2022-09-05_19-49-13
#   done: false
#   experiment_id: 1ad0af4e80e5422d9254d1cd42e38dd8
#   hostname: MSI
#   iterations_since_restore: 42
#   node_ip: 172.24.150.175
#   pid: 30238
#   should_checkpoint: true
#   time_since_restore: 36.95084738731384
#   time_this_iter_s: 0.8622617721557617
#   time_total_s: 36.95084738731384
#   timestamp: 1662382153
#   timesteps_since_restore: 0
#   train_loss: 1.4642986413594838
#   training_iteration: 42
#   trial_id: 0baf6_00002
#   val_acc: 0.23952975753122704
#   val_loss: 1.513989578593861
#   val_weighted_f1: 0.1853297749108712
#   warmup_time: 0.0031316280364990234
#
# Result for train_0baf6_00003:
#   date: 2022-09-05_19-49-13
#   done: false
#   experiment_id: 6cfa0e02f14241c5bc9a298bdc945322
#   hostname: MSI
#   iterations_since_restore: 25
#   node_ip: 172.24.150.175
#   pid: 30241
#   should_checkpoint: true
#   time_since_restore: 37.154764890670776
#   time_this_iter_s: 1.3299880027770996
#   time_total_s: 37.154764890670776
#   timestamp: 1662382153
#   timesteps_since_restore: 0
#   train_loss: 5.322142085513553
#   training_iteration: 25
#   trial_id: 0baf6_00003
#   val_acc: 0.26451138868479057
#   val_loss: 3.424499739300121
#   val_weighted_f1: 0.13822837695271642
#   warmup_time: 0.004381895065307617
#
# Result for train_0baf6_00000:
#   date: 2022-09-05_19-49-15
#   done: false
#   experiment_id: 6bd7c4f9da5b45f9a7bf13f058dd95cd
#   hostname: MSI
#   iterations_since_restore: 59
#   node_ip: 172.24.150.175
#   pid: 30209
#   should_checkpoint: true
#   time_since_restore: 41.02442908287048
#   time_this_iter_s: 0.6937625408172607
#   time_total_s: 41.02442908287048
#   timestamp: 1662382155
#   timesteps_since_restore: 0
#   train_loss: 6.845623595489038
#   training_iteration: 59
#   trial_id: 0baf6_00000
#   val_acc: 0.3769287288758266
#   val_loss: 5.58910439231179
#   val_weighted_f1: 0.28022117145260145
#   warmup_time: 0.002660036087036133
#
# Result for train_0baf6_00004:
#   date: 2022-09-05_19-49-16
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 60
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 40.737611055374146
#   time_this_iter_s: 0.6943082809448242
#   time_total_s: 40.737611055374146
#   timestamp: 1662382156
#   timesteps_since_restore: 0
#   train_loss: 1.8375235401295327
#   training_iteration: 60
#   trial_id: 0baf6_00004
#   val_acc: 0.2490815576781778
#   val_loss: 1.8406949260018088
#   val_weighted_f1: 0.0993395859445909
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00001:
#   date: 2022-09-05_19-49-17
#   done: false
#   experiment_id: 463ac68dc8884a55bc94b18ae18f3af9
#   hostname: MSI
#   iterations_since_restore: 57
#   node_ip: 172.24.150.175
#   pid: 30236
#   should_checkpoint: true
#   time_since_restore: 41.27650594711304
#   time_this_iter_s: 0.5494589805603027
#   time_total_s: 41.27650594711304
#   timestamp: 1662382157
#   timesteps_since_restore: 0
#   train_loss: 0.9469935148954391
#   training_iteration: 57
#   trial_id: 0baf6_00001
#   val_acc: 0.5951506245407788
#   val_loss: 0.9006382497874174
#   val_weighted_f1: 0.516884114501244
#   warmup_time: 0.0032007694244384766
#
# Result for train_0baf6_00002:
#   date: 2022-09-05_19-49-18
#   done: false
#   experiment_id: 1ad0af4e80e5422d9254d1cd42e38dd8
#   hostname: MSI
#   iterations_since_restore: 48
#   node_ip: 172.24.150.175
#   pid: 30238
#   should_checkpoint: true
#   time_since_restore: 41.97922658920288
#   time_this_iter_s: 0.8849544525146484
#   time_total_s: 41.97922658920288
#   timestamp: 1662382158
#   timesteps_since_restore: 0
#   train_loss: 1.4528619606752653
#   training_iteration: 48
#   trial_id: 0baf6_00002
#   val_acc: 0.35635562086700956
#   val_loss: 1.4294339364225215
#   val_weighted_f1: 0.25472884067391455
#   warmup_time: 0.0031316280364990234
#
# Result for train_0baf6_00003:
#   date: 2022-09-05_19-49-18
#   done: false
#   experiment_id: 6cfa0e02f14241c5bc9a298bdc945322
#   hostname: MSI
#   iterations_since_restore: 29
#   node_ip: 172.24.150.175
#   pid: 30241
#   should_checkpoint: true
#   time_since_restore: 42.54443311691284
#   time_this_iter_s: 1.357511043548584
#   time_total_s: 42.54443311691284
#   timestamp: 1662382158
#   timesteps_since_restore: 0
#   train_loss: 1.477343616453377
#   training_iteration: 29
#   trial_id: 0baf6_00003
#   val_acc: 0.5003673769287289
#   val_loss: 1.4268705682321028
#   val_weighted_f1: 0.41755683137089267
#   warmup_time: 0.004381895065307617
#
# Result for train_0baf6_00000:
#   date: 2022-09-05_19-49-21
#   done: false
#   experiment_id: 6bd7c4f9da5b45f9a7bf13f058dd95cd
#   hostname: MSI
#   iterations_since_restore: 68
#   node_ip: 172.24.150.175
#   pid: 30209
#   should_checkpoint: true
#   time_since_restore: 46.59762477874756
#   time_this_iter_s: 0.6359009742736816
#   time_total_s: 46.59762477874756
#   timestamp: 1662382161
#   timesteps_since_restore: 0
#   train_loss: 1.740777990302524
#   training_iteration: 68
#   trial_id: 0baf6_00000
#   val_acc: 0.5841293166789125
#   val_loss: 1.6241044131192295
#   val_weighted_f1: 0.5748483320738148
#   warmup_time: 0.002660036087036133
#
# Result for train_0baf6_00004:
#   date: 2022-09-05_19-49-22
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 69
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 46.35451531410217
#   time_this_iter_s: 0.6238224506378174
#   time_total_s: 46.35451531410217
#   timestamp: 1662382162
#   timesteps_since_restore: 0
#   train_loss: 1.8374377867660008
#   training_iteration: 69
#   trial_id: 0baf6_00004
#   val_acc: 0.2490815576781778
#   val_loss: 1.840694936839017
#   val_weighted_f1: 0.0993395859445909
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00001:
#   date: 2022-09-05_19-49-22
#   done: false
#   experiment_id: 463ac68dc8884a55bc94b18ae18f3af9
#   hostname: MSI
#   iterations_since_restore: 65
#   node_ip: 172.24.150.175
#   pid: 30236
#   should_checkpoint: true
#   time_since_restore: 46.71792817115784
#   time_this_iter_s: 0.6630630493164062
#   time_total_s: 46.71792817115784
#   timestamp: 1662382162
#   timesteps_since_restore: 0
#   train_loss: 0.9443630942621747
#   training_iteration: 65
#   trial_id: 0baf6_00001
#   val_acc: 0.6539309331373989
#   val_loss: 0.8454294990409504
#   val_weighted_f1: 0.6456455382823441
#   warmup_time: 0.0032007694244384766
#
# Result for train_0baf6_00002:
#   date: 2022-09-05_19-49-23
#   done: false
#   experiment_id: 1ad0af4e80e5422d9254d1cd42e38dd8
#   hostname: MSI
#   iterations_since_restore: 55
#   node_ip: 172.24.150.175
#   pid: 30238
#   should_checkpoint: true
#   time_since_restore: 47.77490234375
#   time_this_iter_s: 0.9242937564849854
#   time_total_s: 47.77490234375
#   timestamp: 1662382163
#   timesteps_since_restore: 0
#   train_loss: 1.4381756871133238
#   training_iteration: 55
#   trial_id: 0baf6_00002
#   val_acc: 0.32402645113886847
#   val_loss: 1.4015740101987666
#   val_weighted_f1: 0.28892354412178745
#   warmup_time: 0.0031316280364990234
#
# Result for train_0baf6_00003:
#   date: 2022-09-05_19-49-24
#   done: false
#   experiment_id: 6cfa0e02f14241c5bc9a298bdc945322
#   hostname: MSI
#   iterations_since_restore: 33
#   node_ip: 172.24.150.175
#   pid: 30241
#   should_checkpoint: true
#   time_since_restore: 48.1012749671936
#   time_this_iter_s: 1.3584601879119873
#   time_total_s: 48.1012749671936
#   timestamp: 1662382164
#   timesteps_since_restore: 0
#   train_loss: 1.456442560698535
#   training_iteration: 33
#   trial_id: 0baf6_00003
#   val_acc: 0.4518736223365173
#   val_loss: 1.4491594325412402
#   val_weighted_f1: 0.365442156701363
#   warmup_time: 0.004381895065307617
#
# Result for train_0baf6_00000:
#   date: 2022-09-05_19-49-26
#   done: false
#   experiment_id: 6bd7c4f9da5b45f9a7bf13f058dd95cd
#   hostname: MSI
#   iterations_since_restore: 76
#   node_ip: 172.24.150.175
#   pid: 30209
#   should_checkpoint: true
#   time_since_restore: 51.61709499359131
#   time_this_iter_s: 0.5811498165130615
#   time_total_s: 51.61709499359131
#   timestamp: 1662382166
#   timesteps_since_restore: 0
#   train_loss: 1.6703367072182733
#   training_iteration: 76
#   trial_id: 0baf6_00000
#   val_acc: 0.5180014695077149
#   val_loss: 1.6836959015239368
#   val_weighted_f1: 0.4922673479781626
#   warmup_time: 0.002660036087036133
#
# Result for train_0baf6_00004:
#   date: 2022-09-05_19-49-27
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 77
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 51.40175461769104
#   time_this_iter_s: 0.6760847568511963
#   time_total_s: 51.40175461769104
#   timestamp: 1662382167
#   timesteps_since_restore: 0
#   train_loss: 1.8374537616162687
#   training_iteration: 77
#   trial_id: 0baf6_00004
#   val_acc: 0.2490815576781778
#   val_loss: 1.8406949043273926
#   val_weighted_f1: 0.0993395859445909
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00001:
#   date: 2022-09-05_19-49-28
#   done: false
#   experiment_id: 463ac68dc8884a55bc94b18ae18f3af9
#   hostname: MSI
#   iterations_since_restore: 73
#   node_ip: 172.24.150.175
#   pid: 30236
#   should_checkpoint: true
#   time_since_restore: 52.18685841560364
#   time_this_iter_s: 0.6496775150299072
#   time_total_s: 52.18685841560364
#   timestamp: 1662382168
#   timesteps_since_restore: 0
#   train_loss: 0.8781720146134093
#   training_iteration: 73
#   trial_id: 0baf6_00001
#   val_acc: 0.6752387950036738
#   val_loss: 0.8306168155236677
#   val_weighted_f1: 0.6678204784896103
#   warmup_time: 0.0032007694244384766
#
# Result for train_0baf6_00002:
#   date: 2022-09-05_19-49-29
#   done: false
#   experiment_id: 1ad0af4e80e5422d9254d1cd42e38dd8
#   hostname: MSI
#   iterations_since_restore: 62
#   node_ip: 172.24.150.175
#   pid: 30238
#   should_checkpoint: true
#   time_since_restore: 53.49743032455444
#   time_this_iter_s: 0.9307506084442139
#   time_total_s: 53.49743032455444
#   timestamp: 1662382169
#   timesteps_since_restore: 0
#   train_loss: 1.431667760417268
#   training_iteration: 62
#   trial_id: 0baf6_00002
#   val_acc: 0.28508449669360764
#   val_loss: 1.424936825578863
#   val_weighted_f1: 0.2316642134831474
#   warmup_time: 0.0031316280364990234
#
# Result for train_0baf6_00003:
#   date: 2022-09-05_19-49-29
#   done: false
#   experiment_id: 6cfa0e02f14241c5bc9a298bdc945322
#   hostname: MSI
#   iterations_since_restore: 37
#   node_ip: 172.24.150.175
#   pid: 30241
#   should_checkpoint: true
#   time_since_restore: 53.712770223617554
#   time_this_iter_s: 1.3889844417572021
#   time_total_s: 53.712770223617554
#   timestamp: 1662382169
#   timesteps_since_restore: 0
#   train_loss: 1.4417342108649176
#   training_iteration: 37
#   trial_id: 0baf6_00003
#   val_acc: 0.3651726671565026
#   val_loss: 1.4255437417463823
#   val_weighted_f1: 0.36868849446444446
#   warmup_time: 0.004381895065307617
#
# Result for train_0baf6_00000:
#   date: 2022-09-05_19-49-31
#   done: false
#   experiment_id: 6bd7c4f9da5b45f9a7bf13f058dd95cd
#   hostname: MSI
#   iterations_since_restore: 84
#   node_ip: 172.24.150.175
#   pid: 30209
#   should_checkpoint: true
#   time_since_restore: 56.65696835517883
#   time_this_iter_s: 0.6398959159851074
#   time_total_s: 56.65696835517883
#   timestamp: 1662382171
#   timesteps_since_restore: 0
#   train_loss: 1.6178535609631925
#   training_iteration: 84
#   trial_id: 0baf6_00000
#   val_acc: 0.550330639235856
#   val_loss: 1.5770154216072776
#   val_weighted_f1: 0.5152401784829224
#   warmup_time: 0.002660036087036133
#
# Result for train_0baf6_00004:
#   date: 2022-09-05_19-49-32
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 85
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 56.430676221847534
#   time_this_iter_s: 0.5790150165557861
#   time_total_s: 56.430676221847534
#   timestamp: 1662382172
#   timesteps_since_restore: 0
#   train_loss: 1.837358071997359
#   training_iteration: 85
#   trial_id: 0baf6_00004
#   val_acc: 0.2490815576781778
#   val_loss: 1.8406949043273926
#   val_weighted_f1: 0.0993395859445909
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00001:
#   date: 2022-09-05_19-49-33
#   done: false
#   experiment_id: 463ac68dc8884a55bc94b18ae18f3af9
#   hostname: MSI
#   iterations_since_restore: 81
#   node_ip: 172.24.150.175
#   pid: 30236
#   should_checkpoint: true
#   time_since_restore: 57.596020221710205
#   time_this_iter_s: 0.6742937564849854
#   time_total_s: 57.596020221710205
#   timestamp: 1662382173
#   timesteps_since_restore: 0
#   train_loss: 0.8779109571431134
#   training_iteration: 81
#   trial_id: 0baf6_00001
#   val_acc: 0.6634827332843497
#   val_loss: 0.8313251842151989
#   val_weighted_f1: 0.6546435457620242
#   warmup_time: 0.0032007694244384766
#
# Result for train_0baf6_00002:
#   date: 2022-09-05_19-49-35
#   done: false
#   experiment_id: 1ad0af4e80e5422d9254d1cd42e38dd8
#   hostname: MSI
#   iterations_since_restore: 69
#   node_ip: 172.24.150.175
#   pid: 30238
#   should_checkpoint: true
#   time_since_restore: 59.208301067352295
#   time_this_iter_s: 0.8081586360931396
#   time_total_s: 59.208301067352295
#   timestamp: 1662382175
#   timesteps_since_restore: 0
#   train_loss: 1.421194711247006
#   training_iteration: 69
#   trial_id: 0baf6_00002
#   val_acc: 0.33357825128581925
#   val_loss: 1.4188139817931436
#   val_weighted_f1: 0.27969235879930515
#   warmup_time: 0.0031316280364990234
#
# Result for train_0baf6_00003:
#   date: 2022-09-05_19-49-35
#   done: false
#   experiment_id: 6cfa0e02f14241c5bc9a298bdc945322
#   hostname: MSI
#   iterations_since_restore: 41
#   node_ip: 172.24.150.175
#   pid: 30241
#   should_checkpoint: true
#   time_since_restore: 59.204320669174194
#   time_this_iter_s: 1.3811194896697998
#   time_total_s: 59.204320669174194
#   timestamp: 1662382175
#   timesteps_since_restore: 0
#   train_loss: 1.4238510107671893
#   training_iteration: 41
#   trial_id: 0baf6_00003
#   val_acc: 0.42321822189566494
#   val_loss: 1.4011400721289895
#   val_weighted_f1: 0.3322101934064144
#   warmup_time: 0.004381895065307617
#
# Result for train_0baf6_00000:
#   date: 2022-09-05_19-49-36
#   done: false
#   experiment_id: 6bd7c4f9da5b45f9a7bf13f058dd95cd
#   hostname: MSI
#   iterations_since_restore: 92
#   node_ip: 172.24.150.175
#   pid: 30209
#   should_checkpoint: true
#   time_since_restore: 61.79419016838074
#   time_this_iter_s: 0.7063858509063721
#   time_total_s: 61.79419016838074
#   timestamp: 1662382176
#   timesteps_since_restore: 0
#   train_loss: 1.560475244312673
#   training_iteration: 92
#   trial_id: 0baf6_00000
#   val_acc: 0.588537839823659
#   val_loss: 1.4946301254359158
#   val_weighted_f1: 0.560518099101966
#   warmup_time: 0.002660036087036133
#
# Result for train_0baf6_00004:
#   date: 2022-09-05_19-49-37
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 93
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 61.51105451583862
#   time_this_iter_s: 0.704709529876709
#   time_total_s: 61.51105451583862
#   timestamp: 1662382177
#   timesteps_since_restore: 0
#   train_loss: 1.8374565920314274
#   training_iteration: 93
#   trial_id: 0baf6_00004
#   val_acc: 0.2490815576781778
#   val_loss: 1.8406949043273926
#   val_weighted_f1: 0.0993395859445909
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00001:
#   date: 2022-09-05_19-49-39
#   done: false
#   experiment_id: 463ac68dc8884a55bc94b18ae18f3af9
#   hostname: MSI
#   iterations_since_restore: 89
#   node_ip: 172.24.150.175
#   pid: 30236
#   should_checkpoint: true
#   time_since_restore: 62.98862624168396
#   time_this_iter_s: 0.661548376083374
#   time_total_s: 62.98862624168396
#   timestamp: 1662382179
#   timesteps_since_restore: 0
#   train_loss: 0.8767121675852183
#   training_iteration: 89
#   trial_id: 0baf6_00001
#   val_acc: 0.6693607641440118
#   val_loss: 0.8344634825533087
#   val_weighted_f1: 0.6574197946916479
#   warmup_time: 0.0032007694244384766
#
# Result for train_0baf6_00003:
#   date: 2022-09-05_19-49-40
#   done: false
#   experiment_id: 6cfa0e02f14241c5bc9a298bdc945322
#   hostname: MSI
#   iterations_since_restore: 45
#   node_ip: 172.24.150.175
#   pid: 30241
#   should_checkpoint: true
#   time_since_restore: 64.60123252868652
#   time_this_iter_s: 1.322416067123413
#   time_total_s: 64.60123252868652
#   timestamp: 1662382180
#   timesteps_since_restore: 0
#   train_loss: 1.4042547715676796
#   training_iteration: 45
#   trial_id: 0baf6_00003
#   val_acc: 0.49301983835415136
#   val_loss: 1.3551240888508884
#   val_weighted_f1: 0.4068250783902326
#   warmup_time: 0.004381895065307617
#
# Result for train_0baf6_00002:
#   date: 2022-09-05_19-49-40
#   done: false
#   experiment_id: 1ad0af4e80e5422d9254d1cd42e38dd8
#   hostname: MSI
#   iterations_since_restore: 76
#   node_ip: 172.24.150.175
#   pid: 30238
#   should_checkpoint: true
#   time_since_restore: 64.8671658039093
#   time_this_iter_s: 0.7200219631195068
#   time_total_s: 64.8671658039093
#   timestamp: 1662382180
#   timesteps_since_restore: 0
#   train_loss: 1.4141250969590367
#   training_iteration: 76
#   trial_id: 0baf6_00002
#   val_acc: 0.32696546656869946
#   val_loss: 1.4053009152412415
#   val_weighted_f1: 0.295041833985567
#   warmup_time: 0.0031316280364990234
#
# Result for train_0baf6_00000:
#   date: 2022-09-05_19-49-41
#   done: false
#   experiment_id: 6bd7c4f9da5b45f9a7bf13f058dd95cd
#   hostname: MSI
#   iterations_since_restore: 101
#   node_ip: 172.24.150.175
#   pid: 30209
#   should_checkpoint: true
#   time_since_restore: 67.47166228294373
#   time_this_iter_s: 0.7002151012420654
#   time_total_s: 67.47166228294373
#   timestamp: 1662382181
#   timesteps_since_restore: 0
#   train_loss: 1.512601772272909
#   training_iteration: 101
#   trial_id: 0baf6_00000
#   val_acc: 0.6135194709772226
#   val_loss: 1.5269129818136042
#   val_weighted_f1: 0.5853440954778426
#   warmup_time: 0.002660036087036133
#
# Result for train_0baf6_00004:
#   date: 2022-09-05_19-49-42
#   done: true
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 100
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 65.83197665214539
#   time_this_iter_s: 0.5144431591033936
#   time_total_s: 65.83197665214539
#   timestamp: 1662382182
#   timesteps_since_restore: 0
#   train_loss: 1.837426039818171
#   training_iteration: 100
#   trial_id: 0baf6_00004
#   val_acc: 0.2490815576781778
#   val_loss: 1.8406949043273926
#   val_weighted_f1: 0.0993395859445909
#   warmup_time: 0.004404544830322266
#
# (train pid=30244) Using device: cuda
# Result for train_0baf6_00005:
#   date: 2022-09-05_19-49-42
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 1
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 0.7663195133209229
#   time_this_iter_s: 0.7663195133209229
#   time_total_s: 0.7663195133209229
#   timestamp: 1662382182
#   timesteps_since_restore: 0
#   train_loss: 271.52330558364457
#   training_iteration: 1
#   trial_id: 0baf6_00005
#   val_acc: 0.19985304922850844
#   val_loss: 218.25091552734375
#   val_weighted_f1: 0.066576888414151
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00001:
#   date: 2022-09-05_19-49-44
#   done: false
#   experiment_id: 463ac68dc8884a55bc94b18ae18f3af9
#   hostname: MSI
#   iterations_since_restore: 97
#   node_ip: 172.24.150.175
#   pid: 30236
#   should_checkpoint: true
#   time_since_restore: 68.44708061218262
#   time_this_iter_s: 0.7560083866119385
#   time_total_s: 68.44708061218262
#   timestamp: 1662382184
#   timesteps_since_restore: 0
# ...
#   time_total_s: 119.96109819412231
#   timestamp: 1662382605
#   timesteps_since_restore: 0
#   train_loss: 0.550185627832606
#   training_iteration: 102
#   trial_id: 0baf6_00019
#   val_acc: 0.813372520205731
#   val_loss: 0.5003495243462649
#   val_weighted_f1: 0.8135029280009561
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00011:
#   date: 2022-09-05_19-56-47
#   done: false
#   experiment_id: 463ac68dc8884a55bc94b18ae18f3af9
#   hostname: MSI
#   iterations_since_restore: 237
#   node_ip: 172.24.150.175
#   pid: 30236
#   should_checkpoint: true
#   time_since_restore: 328.28890347480774
#   time_this_iter_s: 1.040034294128418
#   time_total_s: 328.28890347480774
#   timestamp: 1662382607
#   timesteps_since_restore: 0
#   train_loss: 0.5915312092449214
#   training_iteration: 237
#   trial_id: 0baf6_00011
#   val_acc: 0.8199853049228508
#   val_loss: 0.5445807562632994
#   val_weighted_f1: 0.8186964558805528
#   warmup_time: 0.0032007694244384766
#
# Result for train_0baf6_00019:
#   date: 2022-09-05_19-56-50
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 107
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 125.3048186302185
#   time_this_iter_s: 1.054502010345459
#   time_total_s: 125.3048186302185
#   timestamp: 1662382610
#   timesteps_since_restore: 0
#   train_loss: 0.5205302002864916
#   training_iteration: 107
#   trial_id: 0baf6_00019
#   val_acc: 0.7303453343130052
#   val_loss: 0.5989128838885914
#   val_weighted_f1: 0.7127656584551699
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00011:
#   date: 2022-09-05_19-56-52
#   done: false
#   experiment_id: 463ac68dc8884a55bc94b18ae18f3af9
#   hostname: MSI
#   iterations_since_restore: 242
#   node_ip: 172.24.150.175
#   pid: 30236
#   should_checkpoint: true
#   time_since_restore: 333.5824410915375
#   time_this_iter_s: 1.0545024871826172
#   time_total_s: 333.5824410915375
#   timestamp: 1662382612
#   timesteps_since_restore: 0
#   train_loss: 0.5906707211523443
#   training_iteration: 242
#   trial_id: 0baf6_00011
#   val_acc: 0.8214548126377663
#   val_loss: 0.5497866828333248
#   val_weighted_f1: 0.8203714943242482
#   warmup_time: 0.0032007694244384766
#
# Result for train_0baf6_00019:
#   date: 2022-09-05_19-56-56
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 112
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 130.785227060318
#   time_this_iter_s: 1.0799462795257568
#   time_total_s: 130.785227060318
#   timestamp: 1662382616
#   timesteps_since_restore: 0
#   train_loss: 0.5075902888501013
#   training_iteration: 112
#   trial_id: 0baf6_00019
#   val_acc: 0.8508449669360764
#   val_loss: 0.42245057360692456
#   val_weighted_f1: 0.849981262328027
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00011:
#   date: 2022-09-05_19-56-58
#   done: false
#   experiment_id: 463ac68dc8884a55bc94b18ae18f3af9
#   hostname: MSI
#   iterations_since_restore: 247
#   node_ip: 172.24.150.175
#   pid: 30236
#   should_checkpoint: true
#   time_since_restore: 339.15030455589294
#   time_this_iter_s: 1.094977855682373
#   time_total_s: 339.15030455589294
#   timestamp: 1662382618
#   timesteps_since_restore: 0
#   train_loss: 0.5900640834022213
#   training_iteration: 247
#   trial_id: 0baf6_00011
#   val_acc: 0.8126377663482733
#   val_loss: 0.5415952869436957
#   val_weighted_f1: 0.8114996117452015
#   warmup_time: 0.0032007694244384766
#
# Result for train_0baf6_00019:
#   date: 2022-09-05_19-57-01
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 117
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 136.15452933311462
#   time_this_iter_s: 1.075042486190796
#   time_total_s: 136.15452933311462
#   timestamp: 1662382621
#   timesteps_since_restore: 0
#   train_loss: 0.4750661477446556
#   training_iteration: 117
#   trial_id: 0baf6_00019
#   val_acc: 0.8493754592211609
#   val_loss: 0.4129885970191522
#   val_weighted_f1: 0.8460969673355431
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00011:
#   date: 2022-09-05_19-57-03
#   done: false
#   experiment_id: 463ac68dc8884a55bc94b18ae18f3af9
#   hostname: MSI
#   iterations_since_restore: 252
#   node_ip: 172.24.150.175
#   pid: 30236
#   should_checkpoint: true
#   time_since_restore: 344.48393154144287
#   time_this_iter_s: 1.0755774974822998
#   time_total_s: 344.48393154144287
#   timestamp: 1662382623
#   timesteps_since_restore: 0
#   train_loss: 0.5894572265647553
#   training_iteration: 252
#   trial_id: 0baf6_00011
#   val_acc: 0.8052902277736959
#   val_loss: 0.539676612073725
#   val_weighted_f1: 0.8025938193991072
#   warmup_time: 0.0032007694244384766
#
# Result for train_0baf6_00019:
#   date: 2022-09-05_19-57-07
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 122
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 141.498681306839
#   time_this_iter_s: 1.0598199367523193
#   time_total_s: 141.498681306839
#   timestamp: 1662382627
#   timesteps_since_restore: 0
#   train_loss: 0.4634665689758352
#   training_iteration: 122
#   trial_id: 0baf6_00019
#   val_acc: 0.8427626745040412
#   val_loss: 0.4049571291966872
#   val_weighted_f1: 0.8441963421891311
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00011:
#   date: 2022-09-05_19-57-09
#   done: false
#   experiment_id: 463ac68dc8884a55bc94b18ae18f3af9
#   hostname: MSI
#   iterations_since_restore: 257
#   node_ip: 172.24.150.175
#   pid: 30236
#   should_checkpoint: true
#   time_since_restore: 349.79566645622253
#   time_this_iter_s: 1.0492775440216064
#   time_total_s: 349.79566645622253
#   timestamp: 1662382629
#   timesteps_since_restore: 0
#   train_loss: 0.5885113725388372
#   training_iteration: 257
#   trial_id: 0baf6_00011
#   val_acc: 0.813372520205731
#   val_loss: 0.5415729501030662
#   val_weighted_f1: 0.8108115319157483
#   warmup_time: 0.0032007694244384766
#
# Result for train_0baf6_00019:
#   date: 2022-09-05_19-57-12
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 127
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 146.8190062046051
#   time_this_iter_s: 1.075897216796875
#   time_total_s: 146.8190062046051
#   timestamp: 1662382632
#   timesteps_since_restore: 0
#   train_loss: 0.45442321634775884
#   training_iteration: 127
#   trial_id: 0baf6_00019
#   val_acc: 0.8897869213813373
#   val_loss: 0.3401711461218921
#   val_weighted_f1: 0.8893738868081049
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00011:
#   date: 2022-09-05_19-57-14
#   done: false
#   experiment_id: 463ac68dc8884a55bc94b18ae18f3af9
#   hostname: MSI
#   iterations_since_restore: 262
#   node_ip: 172.24.150.175
#   pid: 30236
#   should_checkpoint: true
#   time_since_restore: 355.13108348846436
#   time_this_iter_s: 1.0551748275756836
#   time_total_s: 355.13108348846436
#   timestamp: 1662382634
#   timesteps_since_restore: 0
#   train_loss: 0.5864188020696511
#   training_iteration: 262
#   trial_id: 0baf6_00011
#   val_acc: 0.8170462894930198
#   val_loss: 0.5438511818647385
#   val_weighted_f1: 0.8151268256814532
#   warmup_time: 0.0032007694244384766
#
# Result for train_0baf6_00019:
#   date: 2022-09-05_19-57-17
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 132
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 152.13159728050232
#   time_this_iter_s: 1.0537903308868408
#   time_total_s: 152.13159728050232
#   timestamp: 1662382637
#   timesteps_since_restore: 0
#   train_loss: 0.4421234862828577
#   training_iteration: 132
#   trial_id: 0baf6_00019
#   val_acc: 0.8853783982365907
#   val_loss: 0.3419740565798499
#   val_weighted_f1: 0.8854044253172295
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00011:
#   date: 2022-09-05_19-57-19
#   done: false
#   experiment_id: 463ac68dc8884a55bc94b18ae18f3af9
#   hostname: MSI
#   iterations_since_restore: 267
#   node_ip: 172.24.150.175
#   pid: 30236
#   should_checkpoint: true
#   time_since_restore: 360.4794707298279
#   time_this_iter_s: 1.0602350234985352
#   time_total_s: 360.4794707298279
#   timestamp: 1662382639
#   timesteps_since_restore: 0
#   train_loss: 0.5864683059421746
#   training_iteration: 267
#   trial_id: 0baf6_00011
#   val_acc: 0.8163115356355621
#   val_loss: 0.5426123955033042
#   val_weighted_f1: 0.8140805309226942
#   warmup_time: 0.0032007694244384766
#
# Result for train_0baf6_00019:
#   date: 2022-09-05_19-57-23
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 137
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 157.46955013275146
#   time_this_iter_s: 1.0539145469665527
#   time_total_s: 157.46955013275146
#   timestamp: 1662382643
#   timesteps_since_restore: 0
#   train_loss: 0.4408650844282395
#   training_iteration: 137
#   trial_id: 0baf6_00019
#   val_acc: 0.8978692138133725
#   val_loss: 0.3199316405437209
#   val_weighted_f1: 0.8982207987575361
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00011:
#   date: 2022-09-05_19-57-25
#   done: false
#   experiment_id: 463ac68dc8884a55bc94b18ae18f3af9
#   hostname: MSI
#   iterations_since_restore: 272
#   node_ip: 172.24.150.175
#   pid: 30236
#   should_checkpoint: true
#   time_since_restore: 365.77697587013245
#   time_this_iter_s: 1.0539472103118896
#   time_total_s: 365.77697587013245
#   timestamp: 1662382645
#   timesteps_since_restore: 0
#   train_loss: 0.5862240400668737
#   training_iteration: 272
#   trial_id: 0baf6_00011
#   val_acc: 0.8229243203526818
#   val_loss: 0.5358801822770726
#   val_weighted_f1: 0.8212514678690368
#   warmup_time: 0.0032007694244384766
#
# Result for train_0baf6_00019:
#   date: 2022-09-05_19-57-28
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 142
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 162.76223015785217
#   time_this_iter_s: 1.065101146697998
#   time_total_s: 162.76223015785217
#   timestamp: 1662382648
#   timesteps_since_restore: 0
#   train_loss: 0.4259066294778038
#   training_iteration: 142
#   trial_id: 0baf6_00019
#   val_acc: 0.7472446730345335
#   val_loss: 0.5967411561445757
#   val_weighted_f1: 0.7304867799568757
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00011:
#   date: 2022-09-05_19-57-29
#   done: true
#   experiment_id: 463ac68dc8884a55bc94b18ae18f3af9
#   hostname: MSI
#   iterations_since_restore: 276
#   node_ip: 172.24.150.175
#   pid: 30236
#   should_checkpoint: true
#   time_since_restore: 370.02423763275146
#   time_this_iter_s: 1.082383632659912
#   time_total_s: 370.02423763275146
#   timestamp: 1662382649
#   timesteps_since_restore: 0
#   train_loss: 0.5842612148136705
#   training_iteration: 276
#   trial_id: 0baf6_00011
#   val_acc: 0.8185157972079353
#   val_loss: 0.536305848847736
#   val_weighted_f1: 0.8158532770028001
#   warmup_time: 0.0032007694244384766
#
# Result for train_0baf6_00019:
#   date: 2022-09-05_19-57-33
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 148
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 168.06022214889526
#   time_this_iter_s: 0.8303122520446777
#   time_total_s: 168.06022214889526
#   timestamp: 1662382653
#   timesteps_since_restore: 0
#   train_loss: 0.40970317123306765
#   training_iteration: 148
#   trial_id: 0baf6_00019
#   val_acc: 0.8626010286554004
#   val_loss: 0.36464449898763135
#   val_weighted_f1: 0.8630821889271957
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00019:
#   date: 2022-09-05_19-57-39
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 155
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 173.71036338806152
#   time_this_iter_s: 0.8024678230285645
#   time_total_s: 173.71036338806152
#   timestamp: 1662382659
#   timesteps_since_restore: 0
#   train_loss: 0.33759912324918284
#   training_iteration: 155
#   trial_id: 0baf6_00019
#   val_acc: 0.9022777369581191
#   val_loss: 0.29055704989216546
#   val_weighted_f1: 0.9018793358006887
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00019:
#   date: 2022-09-05_19-57-44
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 162
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 179.209214925766
#   time_this_iter_s: 0.7865431308746338
#   time_total_s: 179.209214925766
#   timestamp: 1662382664
#   timesteps_since_restore: 0
#   train_loss: 0.33143347834010384
#   training_iteration: 162
#   trial_id: 0baf6_00019
#   val_acc: 0.9037472446730346
#   val_loss: 0.2884730791503733
#   val_weighted_f1: 0.9032530025776665
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00019:
#   date: 2022-09-05_19-57-50
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 169
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 184.72143626213074
#   time_this_iter_s: 0.8362534046173096
#   time_total_s: 184.72143626213074
#   timestamp: 1662382670
#   timesteps_since_restore: 0
#   train_loss: 0.3289753905421979
#   training_iteration: 169
#   trial_id: 0baf6_00019
#   val_acc: 0.8941954445260838
#   val_loss: 0.2994902086528865
#   val_weighted_f1: 0.894485682872512
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00019:
#   date: 2022-09-05_19-57-55
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 176
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 190.1442539691925
#   time_this_iter_s: 0.7623260021209717
#   time_total_s: 190.1442539691925
#   timestamp: 1662382675
#   timesteps_since_restore: 0
#   train_loss: 0.32678703047536517
#   training_iteration: 176
#   trial_id: 0baf6_00019
#   val_acc: 0.9096252755326966
#   val_loss: 0.28051187707619235
#   val_weighted_f1: 0.9090633151356152
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00019:
#   date: 2022-09-05_19-58-01
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 183
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 195.83151006698608
#   time_this_iter_s: 0.763498067855835
#   time_total_s: 195.83151006698608
#   timestamp: 1662382681
#   timesteps_since_restore: 0
#   train_loss: 0.32296462558411265
#   training_iteration: 183
#   trial_id: 0baf6_00019
#   val_acc: 0.9103600293901543
#   val_loss: 0.2749457813122056
#   val_weighted_f1: 0.9100388864485564
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00019:
#   date: 2022-09-05_19-58-06
#   done: false
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 190
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 201.30546379089355
#   time_this_iter_s: 0.8144888877868652
#   time_total_s: 201.30546379089355
#   timestamp: 1662382686
#   timesteps_since_restore: 0
#   train_loss: 0.321169877676545
#   training_iteration: 190
#   trial_id: 0baf6_00019
#   val_acc: 0.9052167523879501
#   val_loss: 0.2741535637866367
#   val_weighted_f1: 0.9054367116786692
#   warmup_time: 0.004404544830322266
#
# Result for train_0baf6_00019:
#   date: 2022-09-05_19-58-11
#   done: true
#   experiment_id: 3c4158612a274806ad4205dedec1348c
#   hostname: MSI
#   iterations_since_restore: 196
#   node_ip: 172.24.150.175
#   pid: 30244
#   should_checkpoint: true
#   time_since_restore: 206.14283347129822
#   time_this_iter_s: 0.8188779354095459
#   time_total_s: 206.14283347129822
#   timestamp: 1662382691
#   timesteps_since_restore: 0
#   train_loss: 0.3171681244228337
#   training_iteration: 196
#   trial_id: 0baf6_00019
#   val_acc: 0.9125642909625276
#   val_loss: 0.269253671169281
#   val_weighted_f1: 0.9119572192332976
#   warmup_time: 0.004404544830322266
# 2022-09-05 19:58:11,863	INFO tune.py:758 -- Total run time: 580.69 seconds (580.54 seconds for the tuning loop).

# %% [markdown]
# ## Test Section

# %% [markdown]
# ### Data Loader

# %%
def load_test_data(data_dir="DryBeanDataset", batch_size=1):
    df_test = pd.read_csv(os.path.join(data_dir, "dry_bean_test.csv"))

    ds_test = df_to_dataset(df_test)
    # Create PyTorch data loader
    loader_test = DataLoader(ds_test, batch_size=batch_size)
    return loader_test

# %% [markdown]
# ### Test the best result

# %%
def test_best_model(best_result):
    # Load the data
    loader_test = load_test_data()
    # Which device we will use for training process (CPU/GPU)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print("Using device:", device)
    # Create the model
    model = models.models[best_result.config["arch"]](n_features=len(x_names), n_classes=len(y_classes))
    # Move the model from CPU to the device
    # Actually, only required if the device is not CPU and has no effect if it is CPU
    model = model.to(device)
    # Load the trained weights of the model parameters
    weight_path = os.path.join(best_result.checkpoint.to_directory(), "checkpoint.pt")
    model_state, _ = torch.load(weight_path)
    model.load_state_dict(model_state)
    # The testing process
    # We don't need gradients for the model testing process
    model.eval()
    y_true = []
    y_pred = []
    with torch.no_grad():
        for i, vdata in tqdm(enumerate(loader_test)):
            vinputs, vlabels = vdata
            y_true.extend(vlabels.numpy().tolist())
            voutputs = model(vinputs.to(device))
            # the class with the highest energy is what we choose as prediction
            _, predicted = torch.max(voutputs.data, 1)
            y_pred.extend(predicted.cpu().numpy().tolist())

    # Calculate our classification metrics
    acc = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, average="weighted")
    print(f'Accuracy: {acc}, Weighted F1: {f1}')

# %%
best_result = results.get_best_result("val_loss", "min")

print("Best trial config: {}".format(best_result.config))
print("Best trial final validation loss: {}".format(
    best_result.metrics["val_loss"]))
print("Best trial final validation accuracy: {}".format(
    best_result.metrics["val_acc"]))
print("Best trial final validation weighted F1: {}".format(
    best_result.metrics["val_weighted_f1"]))

test_best_model(best_result)
# Out:
# Best trial config: {'arch': 'MLP6Layers', 'init_lr': 0.00013011698059279522, 'beta_1': 0.6271696733634531, 'beta_2': 0.6816242674528422, 'max_epochs': 1000}
# Best trial final validation loss: 0.269253671169281
# Best trial final validation accuracy: 0.9125642909625276
# Best trial final validation weighted F1: 0.9119572192332976
# Using device: cuda
# 0it [00:00, ?it/s]
# Accuracy: 0.9011756061719324, Weighted F1: 0.9010291180764783

# %% [markdown]
# ## References
# [1] https://pytorch.org/tutorials/beginner/introyt/trainingyt.html
